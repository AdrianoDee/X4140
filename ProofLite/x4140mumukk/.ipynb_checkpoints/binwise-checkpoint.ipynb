# %%
! . /usr/local/bin/thisroot.sh
import ROOT
from ROOT import TFile,TH1,TH1F,TCanvas,TLine,TLegend,TPad
from ROOT import RooFit
import matplotlib.pyplot as plt
import numpy as np

# %%
from ROOT import RooRealVar,RooAbsPdf,RooChebychev,RooExponential,RooGaussian
from ROOT import RooAbsPdf,RooPlot,RooAddPdf,RooDataHist,RooArgSet,RooArgList
from ROOT import RooVoigtian
from ROOT import kGreen,kRed,kBlack,kBlue,kDashed,kDotted,kMagenta
from ROOT.RooFit import Components,LineColor,LineStyle,Name,Normalization,Layout,Format,Label,Parameters,Range,Title

# %%
! ls -trl X4140*.root
# Out:
# -rw-r--r--  1 adrianodiflorio  staff  1712861 19 Ott 13:07 X4140_MuMuKK_KRe_MuMixed_NP3_Alpha99.root
# -rw-r--r--  1 adrianodiflorio  staff  3160565 19 Ott 15:13 X4140_MuMuKK_KRe_MuMixed_NP3.5_Alpha99_CW5.2-5.55.root
# -rw-r--r--  1 adrianodiflorio  staff  1636569 24 Ott 19:17 X4140_MuMuKK_KRe_MuRef_EtaX1.1_NP3.5_Alpha99_CW5.2-5.55.root
# -rw-r--r--  1 adrianodiflorio  staff  1518863 24 Ott 21:40 X4140_MuMuKK_KRe_MuRef_EtaX1.1_NP3.5_Alpha99_CW5.2-5.55_2.root
# -rw-r--r--  1 adrianodiflorio  staff  2621160 28 Ott 10:11 X4140_MuMuKK_KRe_MuRef_NP3.5_Alpha99_DM_CW5.15-5.55.root
# -rw-r--r--  1 adrianodiflorio  staff   207231 16 Nov 13:07 X4140_MuMuKK_KRe_MuRef_Sidebands_NP3.5_Alpha99_CW5.15-5.55.root
# -rw-r--r--  1 adrianodiflorio  staff  3044497 17 Nov 17:46 X4140_Base_KRe_MuRef_NoQual_Sidebands5-7_NP3.0_B0Cuts_CW5.15-5.55.root
# -rw-r--r--  1 adrianodiflorio  staff  4965973 18 Nov 15:17 X4140_Base_KRe_MuRef_NoQual_Sidebands4-6_NP3.0_B0Cuts_CW5.15-5.55_BCDData.root
# -rw-r--r--  1 adrianodiflorio  staff  4418017 28 Nov 13:13 X4140_Base_Ref_NoQual_Side4-6_NP3.0_CW5.15-5.55_BinWise_XnP_B.root
# -rw-r--r--  1 adrianodiflorio  staff  4674984 28 Nov 13:14 X4140_Base_Ref_NoQual_Side4-6_NP3.0_CW5.15-5.55_BinWise_XnP_C.root
# -rw-r--r--  1 adrianodiflorio  staff  4666031 28 Nov 13:14 X4140_Base_Ref_NoQual_Side4-6_NP3.0_CW5.15-5.55_BinWise_XnP_D.root
# -rw-r--r--  1 adrianodiflorio  staff  5133288 28 Nov 13:15 X4140_Base_Ref_NoQual_Side4-6_NP3.0_CW5.15-5.55_BinWise_XnP.root

# %%
rootfile = "X4140_Base_Ref_NoQual_Side4-6_NP3.0_CW5.15-5.55_BinWise_XnP.root"
#rootfile ="../rootfiles/X4140_MuMuKK_KRe_MuRef_Sidebands5-7_NP3.0_B0Cuts_CW5.15-5.55.root"
#histname = "Xcand_histo_hlt8_cw_nonprompt_cosalpha"
#histname = "Phi_hist_all_cw_all_cosalpha"
#histname = "PhiMassHisto"
#histname = "SW_PhiMass_NoM"
histname = "SW_PhiMass_BinWise_"
#histname = "Xcand_histo_DM_any_cw_nonprompt_cosalpha"
inputfile  = TFile(rootfile,"READ")

# %%
massmin = 1.020-0.031
massmax = 1.020+0.031
phimean = 1.020
mass = RooRealVar("mass","M(KK)[GeV]",massmin,massmax)
#mass.setBins(int(massbins))
yieldmap = {}
notRebin = True

# %%
j = 6
for i in range(j,j+1):
    notRebin = True
    c = TCanvas("canvas","canvas",1200,900) ;
    pullpad = TPad("pullpad","pullpad",0.0,0.05,1.0,0.33)
    plotpad = TPad("histopad","histopad",0.0,0.35,1.0,1.0)
    plotpad.SetFillStyle(4004)
    pullpad.SetFillStyle(4004)
    plotpad.Draw()
    pullpad.Draw()
    
    xMin =  4.0 + i*(1.0)/50.0
    xMax = 4.0 + (i+1)*(1.0)/50.0
    histno = histname + str(i)
    hist = inputfile.Get(histno)
    
    #if notRebin:
    #    hist.Rebin(2)
    #    notRebin = False
        
    hist.SetMarkerStyle(ROOT.kFullCircle)
    hist.SetMarkerSize(1.25)
    hist.SetLineColor(kBlack)
    hist.GetXaxis().SetRangeUser(massmin,massmax)
    hist.Draw("E0")
    #c.SaveAs("plots/" + histno + "_" + str(xMin) + "_" + str(xMax) + ".png")
    #c.Clear()

    masslist = RooArgList(mass)
    dh = RooDataHist("dh","dh",masslist,hist)
    
    massbins = (massmax - massmin)/hist.GetBinWidth(2)
    
    mean = RooRealVar("mean","mean of gaussian",phimean,phimean-0.005,phimean+0.005);
    sigma = RooRealVar("sigma","width of gaussian",0.0013);
    sigma1 = RooRealVar("sigma1","width of gaussian1",0.002,0.0005,0.05);
    sigma2 = RooRealVar("sigma2","width of gaussian2",0.004,0.004,0.01);
    gamma = RooRealVar("gamma","gamma of bw",0.005,0.001,0.01);

    a0 = RooRealVar("a0","a0",0.001,-1.,1.)
    a1 = RooRealVar("a1","a1",0.001,-0.5,0.5)
    a2 = RooRealVar("a2","a2",-0.00001,-2.,2.)
    a3 = RooRealVar("a3","a3",0.0)
    a4 = RooRealVar("a4","a4",0.002,-0.1,0.1)
    a5 = RooRealVar("a5","a5",0.001,-0.025,0.05)
    a6 = RooRealVar("a6","a6",0.0,-0.001,0.001)

    aset = RooArgList(a0,a1,a2,a3,a4)#,a6)
    nSig = RooRealVar("nSig","nSig",5E5,0.,5.0E6)
    nBkg = RooRealVar("nBkg","nBkg",2E6,0.,5.0E6)
    
    cheb = RooChebychev("cheb","Background",mass,aset)
    #gauss = RooGaussian("gauss","gaussian PDF ",mass,mean,sigma)
    signal = RooVoigtian("signal","signal",mass,mean,gamma,sigma)

    tot = RooAddPdf("tot","g+cheb",RooArgList(signal,cheb),RooArgList(nSig,nBkg))
    
    tot.fitTo(dh)
    
    massFrame = mass.frame()
    massFrame.SetTitle("Phi signal - " + histno)
    
    dh.plotOn(massFrame,Name("Data"))
    if nSig.getValV() > 1:
        tot.plotOn(massFrame,Name("Pdf"))
    massFrame.GetYaxis().SetTitleOffset(1.3)
    #gauss.plotOn(massFrame,LineColor(kGreen),LineStyle(kDashed),Normalization((sFrac.getValV()*numEvts)/(numEvts)))
    #cheb.plotOn(massFrame,LineColor(kMagenta),LineStyle(kDotted),Normalization(((1.0-sFrac.getValV())*numEvts)/(numEvts)))
    #signal.plotOn(massFrame,LineColor(kGreen),LineStyle(kDashed),Normalization((nSig.getValV())/(numEvts)))
    #cheb.plotOn(massFrame,LineColor(kGreen),LineStyle(kDashed),Normalization((nBkg.getValV())/(numEvts)))
    #massFrame.paramOn()
    plotpad.cd()
    massFrame.Draw()
    
    yieldmap[(xMin,xMax)] = nSig.getValV()
    
    
    hpull = massFrame.pullHist("Data","Pdf")
    pullframe = mass.frame(Title("Pull Distribution"))
    #pullframe.GetXaxis().SetTitleSize(0.04)
    #pullframe.GetYaxis().SetTitleSize(0.03)
    ROOT.gStyle.SetTitleFontSize(0.07)
    pullpad.cd()
    pullframe.addPlotable(hpull,"P")
    pullframe.Draw()

        
    c.cd()
    c.SaveAs("plots/" + histno + "_fit.png")
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-50769a15834b> in <module>()
#      63     dh.plotOn(massFrame,Name("Data"))
#      64     if nSig.getValV() > 1:
# ---> 65         tot.plotOn(massFrame,Name("Pdf"))
#      66     massFrame.GetYaxis().SetTitleOffset(1.3)
#      67     #gauss.plotOn(massFrame,LineColor(kGreen),LineStyle(kDashed),Normalization((sFrac.getValV()*numEvts)/(numEvts)))
#
# KeyboardInterrupt:
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(dh): fit range of variable mass expanded to nearest bin boundaries: [0.989,1.051] --> [0.989,1.051]
# [#1] INFO:Minization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (signal,cheb)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 a0           1.00000e-03  2.00000e-01   -1.00000e+00  1.00000e+00
#      2 a1           1.00000e-03  1.00000e-01   -5.00000e-01  5.00000e-01
#      3 a2          -1.00000e-05  4.00000e-01   -2.00000e+00  2.00000e+00
#      4 a4           2.00000e-03  2.00000e-02   -1.00000e-01  1.00000e-01
#      5 gamma        5.00000e-03  9.00000e-04    1.00000e-03  1.00000e-02
#      6 mean         1.02000e+00  1.00000e-03    1.01500e+00  1.02500e+00
#      7 nBkg         2.00000e+06  5.00000e+05    0.00000e+00  5.00000e+06
#      8 nSig         5.00000e+05  2.50000e+05    0.00000e+00  5.00000e+06
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        4000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=2.22302e+06 FROM MIGRAD    STATUS=INITIATE       30 CALLS          31 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0           1.00000e-03   2.00000e-01   2.01358e-01   3.90374e+03
#    2  a1           1.00000e-03   1.00000e-01   2.01358e-01   9.46715e+02
#    3  a2          -1.00000e-05   4.00000e-01   2.01358e-01  -7.74262e+03
#    4  a4           2.00000e-03   2.00000e-02   2.01400e-01   9.30870e+00
#    5  gamma        5.00000e-03   9.00000e-04   2.02684e-01  -1.34514e+02
#    6  mean         1.02000e+00   1.00000e-03   2.01358e-01   7.77516e+02
#    7  nBkg         2.00000e+06   5.00000e+05   2.05758e-01   2.43432e+06
#    8  nSig         5.00000e+05   2.50000e+05   1.72186e-01   1.48963e+06
#                                ERR DEF= 0.5
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.960714, a1=-0.396901, a2=0.657233, a4=-0.0147941, gamma=0.0062984, mean=1.01733, nBkg=4.92859e+06, nSig=12871.8
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.008787), forcing value to zero @ x=mass=1.03675, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.030484), forcing value to zero @ x=mass=1.03725, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.050265), forcing value to zero @ x=mass=1.03775, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.068077), forcing value to zero @ x=mass=1.03825, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.083865), forcing value to zero @ x=mass=1.03875, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.097578), forcing value to zero @ x=mass=1.03925, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.109164), forcing value to zero @ x=mass=1.03975, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.118573), forcing value to zero @ x=mass=1.04025, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.125756), forcing value to zero @ x=mass=1.04075, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.130665), forcing value to zero @ x=mass=1.04125, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.133256), forcing value to zero @ x=mass=1.04175, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#      p.d.f value is less than zero (-0.133481), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.960714,a1 = -0.396901,a2 = 0.657233,a3 = 0,a4 = -0.0147941)
#     ... (remaining 3 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.938542, a1=-0.459563, a2=0.550173, a4=0.0934209, gamma=0.00547292, mean=1.01816, nBkg=15326.4, nSig=9517.1
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.022583), forcing value to zero @ x=mass=1.03975, coefList=(a0 = -0.938542,a1 = -0.459563,a2 = 0.550173,a3 = 0,a4 = 0.0934209)
#      p.d.f value is less than zero (-0.048353), forcing value to zero @ x=mass=1.04025, coefList=(a0 = -0.938542,a1 = -0.459563,a2 = 0.550173,a3 = 0,a4 = 0.0934209)
#      p.d.f value is less than zero (-0.072095), forcing value to zero @ x=mass=1.04075, coefList=(a0 = -0.938542,a1 = -0.459563,a2 = 0.550173,a3 = 0,a4 = 0.0934209)
#      p.d.f value is less than zero (-0.093635), forcing value to zero @ x=mass=1.04125, coefList=(a0 = -0.938542,a1 = -0.459563,a2 = 0.550173,a3 = 0,a4 = 0.0934209)
#      p.d.f value is less than zero (-0.112791), forcing value to zero @ x=mass=1.04175, coefList=(a0 = -0.938542,a1 = -0.459563,a2 = 0.550173,a3 = 0,a4 = 0.0934209)
#      p.d.f value is less than zero (-0.129376), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.938542,a1 = -0.459563,a2 = 0.550173,a3 = 0,a4 = 0.0934209)
#      p.d.f value is less than zero (-0.143190), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.938542,a1 = -0.459563,a2 = 0.550173,a3 = 0,a4 = 0.0934209)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.968328, a1=-0.499957, a2=0.340346, a4=0.0902163, gamma=0.00467049, mean=1.01869, nBkg=3517.03, nSig=40.1145
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.008074), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.968328,a1 = -0.499957,a2 = 0.340346,a3 = 0,a4 = 0.0902163)
#      p.d.f value is less than zero (-0.035275), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.968328,a1 = -0.499957,a2 = 0.340346,a3 = 0,a4 = 0.0902163)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.982616, a1=-0.499995, a2=0.369776, a4=0.0537123, gamma=0.0044819, mean=1.01867, nBkg=12997, nSig=386.446
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.010481), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.982616,a1 = -0.499995,a2 = 0.369776,a3 = 0,a4 = 0.0537123)
#      p.d.f value is less than zero (-0.033745), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.982616,a1 = -0.499995,a2 = 0.369776,a3 = 0,a4 = 0.0537123)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.985048, a1=-0.499982, a2=0.341856, a4=0.0984083, gamma=0.00406967, mean=1.01872, nBkg=13158.4, nSig=514.913
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.027309), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.985048,a1 = -0.499982,a2 = 0.341856,a3 = 0,a4 = 0.0984083)
#      p.d.f value is less than zero (-0.055281), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.985048,a1 = -0.499982,a2 = 0.341856,a3 = 0,a4 = 0.0984083)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.987006, a1=-0.499987, a2=0.300381, a4=0.0779461, gamma=0.00362384, mean=1.01882, nBkg=13197.8, nSig=607.361
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.014001), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.987006,a1 = -0.499987,a2 = 0.300381,a3 = 0,a4 = 0.0779461)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.994561, a1=-0.49999, a2=0.32503, a4=0.0947569, gamma=0.00315381, mean=1.01895, nBkg=13380.8, nSig=691.59
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.020022), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.994561,a1 = -0.49999,a2 = 0.32503,a3 = 0,a4 = 0.0947569)
#      p.d.f value is less than zero (-0.048790), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.994561,a1 = -0.49999,a2 = 0.32503,a3 = 0,a4 = 0.0947569)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.996295, a1=-0.5, a2=0.316861, a4=0.0999776, gamma=0.00249793, mean=1.01913, nBkg=14472.5, nSig=1196.95
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.019720), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.996295,a1 = -0.5,a2 = 0.316861,a3 = 0,a4 = 0.0999776)
#      p.d.f value is less than zero (-0.049325), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.996295,a1 = -0.5,a2 = 0.316861,a3 = 0,a4 = 0.0999776)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999293, a1=-0.499991, a2=0.542363, a4=-0.0991551, gamma=0.00160998, mean=1.01908, nBkg=13274.9, nSig=3084.77
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.005704), forcing value to zero @ x=mass=1.04075, coefList=(a0 = -0.999293,a1 = -0.499991,a2 = 0.542363,a3 = 0,a4 = -0.0991551)
#      p.d.f value is less than zero (-0.012653), forcing value to zero @ x=mass=1.04125, coefList=(a0 = -0.999293,a1 = -0.499991,a2 = 0.542363,a3 = 0,a4 = -0.0991551)
#      p.d.f value is less than zero (-0.018339), forcing value to zero @ x=mass=1.04175, coefList=(a0 = -0.999293,a1 = -0.499991,a2 = 0.542363,a3 = 0,a4 = -0.0991551)
#      p.d.f value is less than zero (-0.022849), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.999293,a1 = -0.499991,a2 = 0.542363,a3 = 0,a4 = -0.0991551)
#      p.d.f value is less than zero (-0.026280), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999293,a1 = -0.499991,a2 = 0.542363,a3 = 0,a4 = -0.0991551)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999807, a1=-0.499999, a2=0.473128, a4=-0.00285555, gamma=0.00184698, mean=1.01899, nBkg=13396.5, nSig=2880.85
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.016932), forcing value to zero @ x=mass=1.04125, coefList=(a0 = -0.999807,a1 = -0.499999,a2 = 0.473128,a3 = 0,a4 = -0.00285555)
#      p.d.f value is less than zero (-0.034027), forcing value to zero @ x=mass=1.04175, coefList=(a0 = -0.999807,a1 = -0.499999,a2 = 0.473128,a3 = 0,a4 = -0.00285555)
#      p.d.f value is less than zero (-0.049591), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.999807,a1 = -0.499999,a2 = 0.473128,a3 = 0,a4 = -0.00285555)
#      p.d.f value is less than zero (-0.063578), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999807,a1 = -0.499999,a2 = 0.473128,a3 = 0,a4 = -0.00285555)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999305, a1=-0.5, a2=0.414547, a4=0.0764176, gamma=0.0021231, mean=1.019, nBkg=13468.4, nSig=2680.67
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.018602), forcing value to zero @ x=mass=1.04125, coefList=(a0 = -0.999305,a1 = -0.5,a2 = 0.414547,a3 = 0,a4 = 0.0764176)
#      p.d.f value is less than zero (-0.045146), forcing value to zero @ x=mass=1.04175, coefList=(a0 = -0.999305,a1 = -0.5,a2 = 0.414547,a3 = 0,a4 = 0.0764176)
#      p.d.f value is less than zero (-0.069871), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.999305,a1 = -0.5,a2 = 0.414547,a3 = 0,a4 = 0.0764176)
#      p.d.f value is less than zero (-0.092618), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999305,a1 = -0.5,a2 = 0.414547,a3 = 0,a4 = 0.0764176)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999195, a1=-0.5, a2=0.377912, a4=0.0946654, gamma=0.00239695, mean=1.01902, nBkg=13469.1, nSig=2642.75
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.001210), forcing value to zero @ x=mass=1.04125, coefList=(a0 = -0.999195,a1 = -0.5,a2 = 0.377912,a3 = 0,a4 = 0.0946654)
#      p.d.f value is less than zero (-0.030964), forcing value to zero @ x=mass=1.04175, coefList=(a0 = -0.999195,a1 = -0.5,a2 = 0.377912,a3 = 0,a4 = 0.0946654)
#      p.d.f value is less than zero (-0.058934), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.999195,a1 = -0.5,a2 = 0.377912,a3 = 0,a4 = 0.0946654)
#      p.d.f value is less than zero (-0.084938), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999195,a1 = -0.5,a2 = 0.377912,a3 = 0,a4 = 0.0946654)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999222, a1=-0.5, a2=0.353818, a4=0.0995317, gamma=0.00269646, mean=1.01903, nBkg=13469.7, nSig=2611.97
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.016859), forcing value to zero @ x=mass=1.04175, coefList=(a0 = -0.999222,a1 = -0.5,a2 = 0.353818,a3 = 0,a4 = 0.0995317)
#      p.d.f value is less than zero (-0.046399), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.999222,a1 = -0.5,a2 = 0.353818,a3 = 0,a4 = 0.0995317)
#      p.d.f value is less than zero (-0.074040), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999222,a1 = -0.5,a2 = 0.353818,a3 = 0,a4 = 0.0995317)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999273, a1=-0.5, a2=0.334106, a4=0.0997829, gamma=0.00299172, mean=1.01902, nBkg=13472.9, nSig=2583.09
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.002808), forcing value to zero @ x=mass=1.04175, coefList=(a0 = -0.999273,a1 = -0.5,a2 = 0.334106,a3 = 0,a4 = 0.0997829)
#      p.d.f value is less than zero (-0.033336), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.999273,a1 = -0.5,a2 = 0.334106,a3 = 0,a4 = 0.0997829)
#      p.d.f value is less than zero (-0.062052), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999273,a1 = -0.5,a2 = 0.334106,a3 = 0,a4 = 0.0997829)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999347, a1=-0.5, a2=0.31548, a4=0.0979717, gamma=0.0032476, mean=1.01901, nBkg=13471.9, nSig=2571
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.019457), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.999347,a1 = -0.5,a2 = 0.31548,a3 = 0,a4 = 0.0979717)
#      p.d.f value is less than zero (-0.049043), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999347,a1 = -0.5,a2 = 0.31548,a3 = 0,a4 = 0.0979717)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999461, a1=-0.5, a2=0.296571, a4=0.0947909, gamma=0.00345191, mean=1.019, nBkg=13458.8, nSig=2589.84
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.004377), forcing value to zero @ x=mass=1.04225, coefList=(a0 = -0.999461,a1 = -0.5,a2 = 0.296571,a3 = 0,a4 = 0.0947909)
#      p.d.f value is less than zero (-0.034751), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999461,a1 = -0.5,a2 = 0.296571,a3 = 0,a4 = 0.0947909)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.99319, a1=-0.499994, a2=0.286833, a4=0.066675, gamma=0.00276185, mean=1.01903, nBkg=14180.6, nSig=1285.85
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000780), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.99319,a1 = -0.499994,a2 = 0.286833,a3 = 0,a4 = 0.066675)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.99319, a1=-0.499994, a2=0.286454, a4=0.066675, gamma=0.00276185, mean=1.01903, nBkg=14180.6, nSig=1285.85
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000545), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.99319,a1 = -0.499994,a2 = 0.286454,a3 = 0,a4 = 0.066675)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.99319, a1=-0.499994, a2=0.284195, a4=0.0685568, gamma=0.00276185, mean=1.01903, nBkg=14180.6, nSig=1285.85
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000704), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.99319,a1 = -0.499994,a2 = 0.284195,a3 = 0,a4 = 0.0685568)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.99319, a1=-0.499994, a2=0.284195, a4=0.0683308, gamma=0.00276185, mean=1.01903, nBkg=14180.6, nSig=1285.85
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000517), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.99319,a1 = -0.499994,a2 = 0.284195,a3 = 0,a4 = 0.0683308)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.997671, a1=-0.5, a2=0.268938, a4=0.0760776, gamma=0.00291307, mean=1.01904, nBkg=13882.1, nSig=1829.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000763), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.997671,a1 = -0.5,a2 = 0.268938,a3 = 0,a4 = 0.0760776)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.998676, a1=-0.5, a2=0.263651, a4=0.0790207, gamma=0.00296651, mean=1.01904, nBkg=13779.4, nSig=2039.81
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000660), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.998676,a1 = -0.5,a2 = 0.263651,a3 = 0,a4 = 0.0790207)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999366, a1=-0.499999, a2=0.258659, a4=0.0816406, gamma=0.00301742, mean=1.01904, nBkg=13682.9, nSig=2248.94
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000242), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999366,a1 = -0.499999,a2 = 0.258659,a3 = 0,a4 = 0.0816406)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999799, a1=-0.499999, a2=0.256163, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000049), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999799,a1 = -0.499999,a2 = 0.256163,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999799, a1=-0.499999, a2=0.256163, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000049), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999799,a1 = -0.499999,a2 = 0.256163,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256389, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000055), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256389,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256389, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000055), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256389,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256163, a4=0.0830169, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000019), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256163,a3 = 0,a4 = 0.0830169)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256163, a4=0.0830169, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000019), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256163,a3 = 0,a4 = 0.0830169)
#
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 1 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1 added to diagonal of error matrix
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.845821, a1=-0.404616, a2=-1.99092, a4=-0.084684, gamma=0.001595, mean=1.02378, nBkg=2.29527e+06, nSig=1.23259e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.043873), forcing value to zero @ x=mass=0.99925, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.104329), forcing value to zero @ x=mass=0.99975, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.156847), forcing value to zero @ x=mass=1.00025, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.201728), forcing value to zero @ x=mass=1.00075, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.239264), forcing value to zero @ x=mass=1.00125, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.269742), forcing value to zero @ x=mass=1.00175, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.293440), forcing value to zero @ x=mass=1.00225, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.310631), forcing value to zero @ x=mass=1.00275, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.321583), forcing value to zero @ x=mass=1.00325, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.326555), forcing value to zero @ x=mass=1.00375, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.325802), forcing value to zero @ x=mass=1.00425, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#      p.d.f value is less than zero (-0.319573), forcing value to zero @ x=mass=1.00475, coefList=(a0 = -0.845821,a1 = -0.404616,a2 = -1.99092,a3 = 0,a4 = -0.084684)
#     ... (remaining 12 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=0.964433, a1=-0.475737, a2=1.24729, a4=-0.054568, gamma=0.00112534, mean=1.02163, nBkg=575332, nSig=303475
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-1.530923), forcing value to zero @ x=mass=0.98925, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#      p.d.f value is less than zero (-1.331098), forcing value to zero @ x=mass=0.98975, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#      p.d.f value is less than zero (-1.136808), forcing value to zero @ x=mass=0.99025, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#      p.d.f value is less than zero (-0.948105), forcing value to zero @ x=mass=0.99075, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#      p.d.f value is less than zero (-0.765037), forcing value to zero @ x=mass=0.99125, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#      p.d.f value is less than zero (-0.587641), forcing value to zero @ x=mass=0.99175, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#      p.d.f value is less than zero (-0.415951), forcing value to zero @ x=mass=0.99225, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#      p.d.f value is less than zero (-0.249993), forcing value to zero @ x=mass=0.99275, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#      p.d.f value is less than zero (-0.089787), forcing value to zero @ x=mass=0.99325, coefList=(a0 = 0.964433,a1 = -0.475737,a2 = 1.24729,a3 = 0,a4 = -0.054568)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.119624, a1=-0.493988, a2=1.92627, a4=0.0198658, gamma=0.00182426, mean=1.02035, nBkg=4.89285e+06, nSig=64254.2
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-1.163409), forcing value to zero @ x=mass=0.98925, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.859270), forcing value to zero @ x=mass=0.98975, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.568311), forcing value to zero @ x=mass=0.99025, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.290275), forcing value to zero @ x=mass=0.99075, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.024906), forcing value to zero @ x=mass=0.99125, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.056668), forcing value to zero @ x=mass=1.02875, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.129461), forcing value to zero @ x=mass=1.02925, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.199320), forcing value to zero @ x=mass=1.02975, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.266054), forcing value to zero @ x=mass=1.03025, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.329471), forcing value to zero @ x=mass=1.03075, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.389377), forcing value to zero @ x=mass=1.03125, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#      p.d.f value is less than zero (-0.445579), forcing value to zero @ x=mass=1.03175, coefList=(a0 = -0.119624,a1 = -0.493988,a2 = 1.92627,a3 = 0,a4 = 0.0198658)
#     ... (remaining 24 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.738951, a1=-0.49854, a2=1.30904, a4=0.0555183, gamma=0.00237796, mean=1.02031, nBkg=2.73633e+06, nSig=10547.5
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.009258), forcing value to zero @ x=mass=0.98925, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.022586), forcing value to zero @ x=mass=1.03125, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.076464), forcing value to zero @ x=mass=1.03175, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.128168), forcing value to zero @ x=mass=1.03225, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.177561), forcing value to zero @ x=mass=1.03275, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.224502), forcing value to zero @ x=mass=1.03325, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.268848), forcing value to zero @ x=mass=1.03375, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.310453), forcing value to zero @ x=mass=1.03425, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.349167), forcing value to zero @ x=mass=1.03475, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.384838), forcing value to zero @ x=mass=1.03525, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.417309), forcing value to zero @ x=mass=1.03575, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#      p.d.f value is less than zero (-0.446420), forcing value to zero @ x=mass=1.03625, coefList=(a0 = -0.738951,a1 = -0.49854,a2 = 1.30904,a3 = 0,a4 = 0.0555183)
#     ... (remaining 15 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.927367, a1=-0.499657, a2=0.817536, a4=0.0705324, gamma=0.00830202, mean=1.01504, nBkg=4.27642e+06, nSig=4.99927e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.014296), forcing value to zero @ x=mass=1.03575, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.049329), forcing value to zero @ x=mass=1.03625, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.082515), forcing value to zero @ x=mass=1.03675, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.113726), forcing value to zero @ x=mass=1.03725, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.142830), forcing value to zero @ x=mass=1.03775, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.169689), forcing value to zero @ x=mass=1.03825, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.194161), forcing value to zero @ x=mass=1.03875, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.216098), forcing value to zero @ x=mass=1.03925, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.235346), forcing value to zero @ x=mass=1.03975, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.251746), forcing value to zero @ x=mass=1.04025, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.265132), forcing value to zero @ x=mass=1.04075, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#      p.d.f value is less than zero (-0.275335), forcing value to zero @ x=mass=1.04125, coefList=(a0 = -0.927367,a1 = -0.499657,a2 = 0.817536,a3 = 0,a4 = 0.0705324)
#     ... (remaining 5 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=0.978942, a1=-0.499925, a2=-0.542868, a4=-0.0770757, gamma=0.0091497, mean=1.01595, nBkg=3.32901e+06, nSig=2.524e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.035496), forcing value to zero @ x=mass=0.99075, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.072336), forcing value to zero @ x=mass=0.99125, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.103665), forcing value to zero @ x=mass=0.99175, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.129762), forcing value to zero @ x=mass=0.99225, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.150895), forcing value to zero @ x=mass=0.99275, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.167326), forcing value to zero @ x=mass=0.99325, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.179305), forcing value to zero @ x=mass=0.99375, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.187075), forcing value to zero @ x=mass=0.99425, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.190871), forcing value to zero @ x=mass=0.99475, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.190918), forcing value to zero @ x=mass=0.99525, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.187434), forcing value to zero @ x=mass=0.99575, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#      p.d.f value is less than zero (-0.180630), forcing value to zero @ x=mass=0.99625, coefList=(a0 = 0.978942,a1 = -0.499925,a2 = -0.542868,a3 = 0,a4 = -0.0770757)
#     ... (remaining 11 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.11637, a1=-0.499986, a2=1.95943, a4=-0.0598953, gamma=0.00632415, mean=1.0173, nBkg=4.0498e+06, nSig=779721
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-1.139021), forcing value to zero @ x=mass=0.98925, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.858003), forcing value to zero @ x=mass=0.98975, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.586634), forcing value to zero @ x=mass=0.99025, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.324912), forcing value to zero @ x=mass=0.99075, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.072829), forcing value to zero @ x=mass=0.99125, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.076857), forcing value to zero @ x=mass=1.02825, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.154778), forcing value to zero @ x=mass=1.02875, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.229351), forcing value to zero @ x=mass=1.02925, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.300368), forcing value to zero @ x=mass=1.02975, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.367625), forcing value to zero @ x=mass=1.03025, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.430920), forcing value to zero @ x=mass=1.03075, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#      p.d.f value is less than zero (-0.490052), forcing value to zero @ x=mass=1.03125, coefList=(a0 = -0.11637,a1 = -0.499986,a2 = 1.95943,a3 = 0,a4 = -0.0598953)
#     ... (remaining 25 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=0.756246, a1=-0.499998, a2=1.62755, a4=-0.016671, gamma=0.00462058, mean=1.01814, nBkg=1.52914e+06, nSig=4.77483e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-1.731350), forcing value to zero @ x=mass=0.98925, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-1.467117), forcing value to zero @ x=mass=0.98975, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-1.212538), forcing value to zero @ x=mass=0.99025, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-0.967504), forcing value to zero @ x=mass=0.99075, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-0.731903), forcing value to zero @ x=mass=0.99125, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-0.505623), forcing value to zero @ x=mass=0.99175, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-0.288546), forcing value to zero @ x=mass=0.99225, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-0.080556), forcing value to zero @ x=mass=0.99275, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-0.005889), forcing value to zero @ x=mass=1.03525, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-0.008469), forcing value to zero @ x=mass=1.03575, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#      p.d.f value is less than zero (-0.006325), forcing value to zero @ x=mass=1.03625, coefList=(a0 = 0.756246,a1 = -0.499998,a2 = 1.62755,a3 = 0,a4 = -0.016671)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=0.336105, a1=-0.5, a2=-1.02765, a4=0.0840639, gamma=0.0038011, mean=1.01858, nBkg=492114, nSig=1.91655e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.007076), forcing value to zero @ x=mass=1.00075, coefList=(a0 = 0.336105,a1 = -0.5,a2 = -1.02765,a3 = 0,a4 = 0.0840639)
#      p.d.f value is less than zero (-0.015351), forcing value to zero @ x=mass=1.00125, coefList=(a0 = 0.336105,a1 = -0.5,a2 = -1.02765,a3 = 0,a4 = 0.0840639)
#      p.d.f value is less than zero (-0.020227), forcing value to zero @ x=mass=1.00175, coefList=(a0 = 0.336105,a1 = -0.5,a2 = -1.02765,a3 = 0,a4 = 0.0840639)
#      p.d.f value is less than zero (-0.021729), forcing value to zero @ x=mass=1.00225, coefList=(a0 = 0.336105,a1 = -0.5,a2 = -1.02765,a3 = 0,a4 = 0.0840639)
#      p.d.f value is less than zero (-0.019890), forcing value to zero @ x=mass=1.00275, coefList=(a0 = 0.336105,a1 = -0.5,a2 = -1.02765,a3 = 0,a4 = 0.0840639)
#      p.d.f value is less than zero (-0.014747), forcing value to zero @ x=mass=1.00325, coefList=(a0 = 0.336105,a1 = -0.5,a2 = -1.02765,a3 = 0,a4 = 0.0840639)
#      p.d.f value is less than zero (-0.006343), forcing value to zero @ x=mass=1.00375, coefList=(a0 = 0.336105,a1 = -0.5,a2 = -1.02765,a3 = 0,a4 = 0.0840639)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.587407, a1=-0.5, a2=-1.88938, a4=-0.0999943, gamma=0.00341262, mean=1.01881, nBkg=4.82959e+06, nSig=4.49638e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.014696), forcing value to zero @ x=mass=0.99825, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.077659), forcing value to zero @ x=mass=0.99875, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.132513), forcing value to zero @ x=mass=0.99925, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.179585), forcing value to zero @ x=mass=0.99975, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.219188), forcing value to zero @ x=mass=1.00025, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.251633), forcing value to zero @ x=mass=1.00075, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.277217), forcing value to zero @ x=mass=1.00125, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.296232), forcing value to zero @ x=mass=1.00175, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.308961), forcing value to zero @ x=mass=1.00225, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.315680), forcing value to zero @ x=mass=1.00275, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.316658), forcing value to zero @ x=mass=1.00325, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#      p.d.f value is less than zero (-0.312155), forcing value to zero @ x=mass=1.00375, coefList=(a0 = -0.587407,a1 = -0.5,a2 = -1.88938,a3 = 0,a4 = -0.0999943)
#     ... (remaining 12 messages suppressed)
#
# ...
#      p.d.f value is less than zero (-0.334480), forcing value to zero @ x=mass=1.03725, coefList=(a0 = -0.897102,a1 = -0.499999,a2 = 1.05217,a3 = 0,a4 = 0.0297555)
#      p.d.f value is less than zero (-0.356045), forcing value to zero @ x=mass=1.03775, coefList=(a0 = -0.897102,a1 = -0.499999,a2 = 1.05217,a3 = 0,a4 = 0.0297555)
#      p.d.f value is less than zero (-0.374437), forcing value to zero @ x=mass=1.03825, coefList=(a0 = -0.897102,a1 = -0.499999,a2 = 1.05217,a3 = 0,a4 = 0.0297555)
#     ... (remaining 11 messages suppressed)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999799, a1=-0.499999, a2=0.256163, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000049), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999799,a1 = -0.499999,a2 = 0.256163,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256389, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000055), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256389,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256163, a4=0.0830169, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000019), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256163,a3 = 0,a4 = 0.0830169)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499953, a2=0.256389, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000051), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499953,a2 = 0.256389,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256389, a4=0.0828915, gamma=0.00310581, mean=1.01904, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000055), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256389,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256389, a4=0.0828915, gamma=0.00304305, mean=1.01909, nBkg=13634.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000055), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256389,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256389, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13670.8, nSig=2357.33
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000055), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256389,a3 = 0,a4 = 0.0828915)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.59204e+06) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.999617, a1=-0.499999, a2=0.256389, a4=0.0828915, gamma=0.00304305, mean=1.01904, nBkg=13634.8, nSig=2386.98
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.000055), forcing value to zero @ x=mass=1.04275, coefList=(a0 = -0.999617,a1 = -0.499999,a2 = 0.256389,a3 = 0,a4 = 0.0828915)
#
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -4.1422e-01  1.5788e-01  9.9989e-01  1.0000e+00  1.0071e+00  1.1536e+00  1.6816e+00  2.4142e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.416632 TO DIAGONAL.
#  FCN=-185223 FROM HESSE     STATUS=NOT POSDEF     67 CALLS         497 TOTAL
#                      EDM=12.8202    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0          -9.99617e-01   1.29643e-06   7.65299e-03   3.90527e+01
#    2  a1          -4.99999e-01   3.34620e-04   1.13881e-02   1.23519e+00
#    3  a2           2.56163e-01   1.95530e-06   1.14105e-04  -1.03978e+03
#    4  a4           8.28915e-02   7.68253e-07   2.24444e-03   3.59079e+01
#    5  gamma        3.04305e-03   2.04636e-04   1.65589e-02  -9.77667e+01
#    6  mean         1.01904e+00   1.16052e-04   1.03468e-02   4.81402e+01
#    7  nBkg         1.36348e+04   1.14463e+02   1.38055e-04   2.94381e+03
#    8  nSig         2.35733e+03   8.10335e+01   2.72284e-04   3.92225e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  MIGRAD TERMINATED WITHOUT CONVERGENCE.
#  FCN=-185246 FROM MIGRAD    STATUS=FAILED        631 CALLS         632 TOTAL
#                      EDM=78.2422    STRATEGY= 1      ERR MATRIX APPROXIMATE
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0          -9.99617e-01   7.24355e-04   1.36483e-03   4.03387e+01
#    2  a1          -5.00000e-01   5.25444e-04   1.36251e-02** at limit **
#    3  a2           2.56162e-01   1.34402e-02   6.12421e-05  -1.13116e+03
#    4  a4           8.28918e-02   6.49974e-03   1.03208e-03   3.99330e+01
#    5  gamma        5.11117e-03   3.76663e-04   1.86859e-02   9.17951e-02
#    6  mean         1.01866e+00   1.66815e-04   9.57716e-03  -4.01212e-01
#    7  nBkg         1.30532e+04   1.71949e+02   1.43151e-04  -2.67276e+00
#    8  nSig         2.69941e+03   1.38831e+02   2.26454e-04  -1.21415e+01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   5.248e-07  3.859e-15  3.537e-07 -3.550e-08 -1.066e-10  2.711e-10  7.407e-05 -7.412e-05
#   3.859e-15  2.868e-14 -1.757e-12 -9.440e-13  2.164e-13 -1.863e-14 -1.214e-07  1.216e-07
#   3.537e-07 -1.757e-12  1.806e-04  3.216e-06  6.656e-07  4.683e-07 -1.719e-01  1.723e-01
#  -3.550e-08 -9.440e-13  3.216e-06  4.244e-05 -8.443e-08  1.733e-07  5.198e-02 -5.206e-02
#  -1.066e-10  2.164e-13  6.656e-07 -8.443e-08  1.422e-07 -1.370e-08 -3.359e-02  3.369e-02
#   2.711e-10 -1.863e-14  4.683e-07  1.733e-07 -1.370e-08  2.784e-08  4.950e-03 -4.964e-03
#   7.407e-05 -1.214e-07 -1.719e-01  5.198e-02 -3.359e-02  4.950e-03  2.957e+04 -1.654e+04
#  -7.412e-05  1.216e-07  1.723e-01 -5.206e-02  3.369e-02 -4.964e-03 -1.654e+04  1.927e+04
# ERR MATRIX APPROXIMATE
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.03829   1.000  0.000  0.036 -0.008 -0.000  0.002  0.001 -0.001
#         2  0.00549   0.000  1.000 -0.001 -0.001  0.003 -0.001 -0.004  0.005
#         3  0.28101   0.036 -0.001  1.000  0.037  0.131  0.209 -0.074  0.092
#         4  0.16283  -0.008 -0.001  0.037  1.000 -0.034  0.159  0.046 -0.058
#         5  0.66248  -0.000  0.003  0.131 -0.034  1.000 -0.218 -0.518  0.643
#         6  0.36607   0.002 -0.001  0.209  0.159 -0.218  1.000  0.173 -0.214
#         7  0.69948   0.001 -0.004 -0.074  0.046 -0.518  0.173  1.000 -0.693
#         8  0.77031  -0.001  0.005  0.092 -0.058  0.643 -0.214 -0.693  1.000
#  ERR MATRIX APPROXIMATE
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        4000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-185246 FROM HESSE     STATUS=OK             61 CALLS         693 TOTAL
#                      EDM=78.2968    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  a0          -9.99617e-01   7.24334e-04   2.72966e-04  -1.54313e+00
#    2  a1          -5.00000e-01   5.25449e-04   2.72502e-03  -1.57079e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    3  a2           2.56162e-01   1.34398e-02   1.22484e-05   1.28434e-01
#    4  a4           8.28918e-02   6.49948e-03   2.06415e-04   2.16442e+00
#    5  gamma        5.11117e-03   3.80644e-04   7.47437e-04  -8.65152e-02
#    6  mean         1.01866e+00   1.66988e-04   1.91543e-03  -2.70401e-01
#    7  nBkg         1.30532e+04   1.73186e+02   2.86302e-05  -1.46856e+00
#    8  nSig         2.69941e+03   1.40182e+02   4.52908e-05  -1.52432e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   5.248e-07  7.520e-16  3.465e-07 -3.491e-08 -1.188e-10  2.654e-10  7.625e-05 -7.626e-05
#   7.520e-16  2.868e-14 -3.436e-13 -1.912e-13  4.514e-14 -3.882e-15 -2.497e-08  2.497e-08
#   3.465e-07 -3.436e-13  1.806e-04  3.159e-06  6.777e-07  4.640e-07 -1.787e-01  1.787e-01
#  -3.491e-08 -1.912e-13  3.159e-06  4.243e-05 -9.002e-08  1.732e-07  5.324e-02 -5.325e-02
#  -1.188e-10  4.514e-14  6.777e-07 -9.002e-08  1.452e-07 -1.433e-08 -3.481e-02  3.483e-02
#   2.654e-10 -3.882e-15  4.640e-07  1.732e-07 -1.433e-08  2.790e-08  5.077e-03 -5.080e-03
#   7.625e-05 -2.497e-08 -1.787e-01  5.324e-02 -3.481e-02  5.077e-03  2.999e+04 -1.695e+04
#  -7.626e-05  2.497e-08  1.787e-01 -5.325e-02  3.483e-02 -5.080e-03 -1.695e+04  1.965e+04
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.03753   1.000  0.000  0.036 -0.007 -0.000  0.002  0.001 -0.001
#         2  0.00111   0.000  1.000 -0.000 -0.000  0.001 -0.000 -0.001  0.001
#         3  0.28093   0.036 -0.000  1.000  0.036  0.132  0.207 -0.077  0.095
#         4  0.16259  -0.007 -0.000  0.036  1.000 -0.036  0.159  0.047 -0.058
#         5  0.67126  -0.000  0.001  0.132 -0.036  1.000 -0.225 -0.527  0.652
#         6  0.36856   0.002 -0.000  0.207  0.159 -0.225  1.000  0.176 -0.217
#         7  0.70466   0.001 -0.001 -0.077  0.047 -0.527  0.176  1.000 -0.698
#         8  0.77535  -0.001  0.001  0.095 -0.058  0.652 -0.217 -0.698  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#0] WARNING:Plotting -- At observable [x]=1.04294 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.011580), forcing value to zero @ x=mass=1.04294, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04356 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.048045), forcing value to zero @ x=mass=1.04356, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04418 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.081806), forcing value to zero @ x=mass=1.04418, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.0448 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.112516), forcing value to zero @ x=mass=1.0448, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04542 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.139807), forcing value to zero @ x=mass=1.04542, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04604 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.163293), forcing value to zero @ x=mass=1.04604, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04666 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.182564), forcing value to zero @ x=mass=1.04666, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04728 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.197192), forcing value to zero @ x=mass=1.04728, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.0479 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.206725), forcing value to zero @ x=mass=1.0479, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04852 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.210689), forcing value to zero @ x=mass=1.04852, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04914 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.208587), forcing value to zero @ x=mass=1.04914, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.04976 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.199899), forcing value to zero @ x=mass=1.04976, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.05038 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]
#      p.d.f value is less than zero (-0.184081), forcing value to zero @ x=mass=1.05038, coefList=(a0 = -0.999617 +/- 0.000724334,a1 = -0.5 +/- 0.000525449,a2 = 0.256162 +/- 0.0134398,a3 = 0,a4 = 0.0828918 +/- 0.00649948)
# [#0] WARNING:Plotting -- At observable [x]=1.051 RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4) ]

# %%
print yieldmap
# Out:
# {(4.26, 4.28): 2886.819838722188, (4.2, 4.22): 2411.870093500801, (4.22, 4.24): 3084.0697929127027, (4.16, 4.18): 1922.082614703169, (4.12, 4.14): 3009.798947381792, (4.1, 4.12): 0.0016218182352645272, (4.14, 4.16): 1645.8751635886615, (4.18, 4.2): 2235.0714436664143, (4.24, 4.26): 3476.7951660602535, (4.08, 4.1): 1.4757639554829893e-06}

# %%
line = TLine()

# %%
hist.GetXaxis().SetRangeUser(massmin,massmax)
hist.Draw()
plotname = "plots/phiplot_" + histname
c.SaveAs(plotname  + ".png")
c.SaveAs(plotname  + ".eps")
c.SaveAs(plotname  + ".pdf")
# Out:
# Info in <TCanvas::Print>: png file plots/phiplot_SW_PhiMass_BinWise_.png has been created
# Info in <TCanvas::Print>: eps file plots/phiplot_SW_PhiMass_BinWise_.eps has been created
# Info in <TCanvas::Print>: pdf file plots/phiplot_SW_PhiMass_BinWise_.pdf has been created

# %%
cheb = RooChebychev("cheb","Background",mass,aset)
#gauss = RooGaussian("gauss","gaussian PDF ",mass,mean,sigma)
signal = RooVoigtian("signal","signal",mass,mean,gamma,sigma)

tot = RooAddPdf("tot","g+cheb",RooArgList(signal,cheb),RooArgList(nSig,nBkg))

# %%
masslist = RooArgList(mass)
dh = RooDataHist("dh","dh",masslist,hist)
numEvts = dh.sum(False)
print numEvts
# Out:
# 2213156.0
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(dh): fit range of variable mass expanded to nearest bin boundaries: [0.989,1.051] --> [0.989,1.051]

# %%
tot.fitTo(dh,Range(massmin,massmax))
# Out:
# [#1] INFO:Minization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Eval -- RooRealVar::setRange(mass) new range named 'fit' created with bounds [0.989,1.051]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_tot_dh) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(mass) new range named 'NormalizationRangeForfit' created with bounds [0.989,1.051]
# [#1] INFO:Eval -- RooRealVar::setRange(mass) new range named 'fit_nll_tot_dh' created with bounds [0.989,1.051]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_tot_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass|NormalizationRangeForfit]_Norm[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (signal,cheb)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 a0           1.00000e-03  2.00000e-01   -1.00000e+00  1.00000e+00
#      2 a1           1.00000e-03  1.00000e-01   -5.00000e-01  5.00000e-01
#      3 a2          -1.00000e-05  4.00000e-01   -2.00000e+00  2.00000e+00
#      4 a4           2.00000e-03  2.00000e-02   -1.00000e-01  1.00000e-01
#      5 a5           1.00000e-03  7.50000e-03   -2.50000e-02  5.00000e-02
#      6 gamma        4.76572e-03  9.00000e-04    1.00000e-03  1.00000e-02
#      7 mean         1.02000e+00  1.00000e-03    1.01500e+00  1.02500e+00
#      8 nBkg         2.00000e+06  5.00000e+05    0.00000e+00  5.00000e+06
#      9 nSig         5.00000e+05  2.50000e+05    0.00000e+00  5.00000e+06
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        4500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-3.62312e+07 FROM MIGRAD    STATUS=INITIATE       60 CALLS          61 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0           1.00000e-03   2.00000e-01   0.00000e+00  -2.51629e+05
#    2  a1           1.00000e-03   1.00000e-01   0.00000e+00  -2.70012e+04
#    3  a2          -1.00000e-05   4.00000e-01   0.00000e+00   2.22710e+05
#    4  a4           2.00000e-03   2.00000e-02   0.00000e+00   5.99358e+03
#    5  a5           4.99978e-02   7.50000e-03   1.87161e+00  -4.05311e+01
#    6  gamma        4.76572e-03   9.00000e-04   0.00000e+00  -4.83606e+04
#    7  mean         1.02000e+00   1.00000e-03   0.00000e+00  -1.22101e+04
#    8  nBkg         2.00000e+06   5.00000e+05   0.00000e+00   1.71973e+05
#    9  nSig         5.00000e+05   2.50000e+05   0.00000e+00   4.39276e+05
#                                ERR DEF= 0.5
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 5 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1.00053 added to diagonal of error matrix
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.61013e+07) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=0.942858, a1=-0.290247, a2=-1.99632, a4=-0.0698513, a5=0.0197722, gamma=0.00851463, mean=1.01519, nBkg=4.66391e+06, nSig=995853
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4,a5) ]
#      p.d.f value is less than zero (-0.074087), forcing value to zero @ x=mass=0.99325, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-0.232527), forcing value to zero @ x=mass=0.99375, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-0.378430), forcing value to zero @ x=mass=0.99425, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-0.512267), forcing value to zero @ x=mass=0.99475, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-0.634494), forcing value to zero @ x=mass=0.99525, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-0.745549), forcing value to zero @ x=mass=0.99575, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-0.845856), forcing value to zero @ x=mass=0.99625, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-0.935823), forcing value to zero @ x=mass=0.99675, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-1.015844), forcing value to zero @ x=mass=0.99725, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-1.086300), forcing value to zero @ x=mass=0.99775, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-1.147556), forcing value to zero @ x=mass=0.99825, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#      p.d.f value is less than zero (-1.199966), forcing value to zero @ x=mass=0.99875, coefList=(a0 = 0.942858,a1 = -0.290247,a2 = -1.99632,a3 = 0,a4 = -0.0698513,a5 = 0.0197722)
#     ... (remaining 33 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.61013e+07) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=0.722374, a1=0.450526, a2=-0.719766, a4=0.0309569, a5=-0.00325334, gamma=0.00272022, mean=1.02064, nBkg=2.31478e+06, nSig=4.75275e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4,a5) ]
#      p.d.f value is less than zero (-0.013556), forcing value to zero @ x=mass=0.99825, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.057352), forcing value to zero @ x=mass=0.99875, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.097748), forcing value to zero @ x=mass=0.99925, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.134768), forcing value to zero @ x=mass=0.99975, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.168442), forcing value to zero @ x=mass=1.00025, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.198801), forcing value to zero @ x=mass=1.00075, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.225882), forcing value to zero @ x=mass=1.00125, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.249722), forcing value to zero @ x=mass=1.00175, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.270365), forcing value to zero @ x=mass=1.00225, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.287854), forcing value to zero @ x=mass=1.00275, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.302237), forcing value to zero @ x=mass=1.00325, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#      p.d.f value is less than zero (-0.313566), forcing value to zero @ x=mass=1.00375, coefList=(a0 = 0.722374,a1 = 0.450526,a2 = -0.719766,a3 = 0,a4 = 0.0309569,a5 = -0.00325334)
#     ... (remaining 21 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.61013e+07) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.836876, a1=0.123942, a2=-1.99241, a4=-0.0745018, a5=0.0336047, gamma=0.00112305, mean=1.02448, nBkg=589275, nSig=4.97202e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4,a5) ]
#      p.d.f value is less than zero (-0.002206), forcing value to zero @ x=mass=0.99875, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.090572), forcing value to zero @ x=mass=0.99925, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.170435), forcing value to zero @ x=mass=0.99975, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.242138), forcing value to zero @ x=mass=1.00025, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.306010), forcing value to zero @ x=mass=1.00075, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.362365), forcing value to zero @ x=mass=1.00125, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.411505), forcing value to zero @ x=mass=1.00175, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.453718), forcing value to zero @ x=mass=1.00225, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.489280), forcing value to zero @ x=mass=1.00275, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.518455), forcing value to zero @ x=mass=1.00325, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.541498), forcing value to zero @ x=mass=1.00375, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#      p.d.f value is less than zero (-0.558651), forcing value to zero @ x=mass=1.00425, coefList=(a0 = -0.836876,a1 = 0.123942,a2 = -1.99241,a3 = 0,a4 = -0.0745018,a5 = 0.0336047)
#     ... (remaining 28 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.61013e+07) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.998684, a1=0.492748, a2=1.47014, a4=-0.0676401, a5=0.0345198, gamma=0.00115114, mean=1.02463, nBkg=207483, nSig=4.91303e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4,a5) ]
#      p.d.f value is less than zero (-0.019523), forcing value to zero @ x=mass=1.02275, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.104024), forcing value to zero @ x=mass=1.02325, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.186568), forcing value to zero @ x=mass=1.02375, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.266995), forcing value to zero @ x=mass=1.02425, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.345146), forcing value to zero @ x=mass=1.02475, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.420869), forcing value to zero @ x=mass=1.02525, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.494012), forcing value to zero @ x=mass=1.02575, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.564429), forcing value to zero @ x=mass=1.02625, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.631976), forcing value to zero @ x=mass=1.02675, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.696514), forcing value to zero @ x=mass=1.02725, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.757904), forcing value to zero @ x=mass=1.02775, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#      p.d.f value is less than zero (-0.816013), forcing value to zero @ x=mass=1.02825, coefList=(a0 = -0.998684,a1 = 0.492748,a2 = 1.47014,a3 = 0,a4 = -0.0676401,a5 = 0.0345198)
#     ... (remaining 36 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.61013e+07) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=0.46191, a1=0.152653, a2=1.99081, a4=-0.0421419, a5=0.0350981, gamma=0.00100523, mean=1.02355, nBkg=1.65501e+06, nSig=4.72549e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4,a5) ]
#      p.d.f value is less than zero (-1.099006), forcing value to zero @ x=mass=0.98925, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.856211), forcing value to zero @ x=mass=0.98975, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.620140), forcing value to zero @ x=mass=0.99025, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.391078), forcing value to zero @ x=mass=0.99075, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.169283), forcing value to zero @ x=mass=0.99125, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.011683), forcing value to zero @ x=mass=1.02475, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.088473), forcing value to zero @ x=mass=1.02525, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.162610), forcing value to zero @ x=mass=1.02575, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.233902), forcing value to zero @ x=mass=1.02625, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.302164), forcing value to zero @ x=mass=1.02675, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.367211), forcing value to zero @ x=mass=1.02725, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#      p.d.f value is less than zero (-0.428863), forcing value to zero @ x=mass=1.02775, coefList=(a0 = 0.46191,a1 = 0.152653,a2 = 1.99081,a3 = 0,a4 = -0.0421419,a5 = 0.0350981)
#     ... (remaining 30 messages suppressed)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MACHINE ACCURACY LIMITS FURTHER IMPROVEMENT.
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-3.63443e+07 FROM HESSE     STATUS=OK             87 CALLS        1086 TOTAL
#                      EDM=0.110426    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0           4.07796e-01   1.35408e-03   5.05799e-03  -4.37673e+00
#    2  a1          -1.60609e-01   1.82506e-03   1.03773e-02  -2.49537e+00
#    3  a2           4.61267e-02   1.20856e-03   2.07958e-03  -5.90824e+01
#    4  a4           1.41075e-02   1.14002e-03   4.16805e-02  -1.11712e+00
#    5  a5          -1.44395e-02   1.33634e-03   1.59879e-01   9.28780e+00
#    6  gamma        2.92534e-03   1.70890e-04   1.02879e-01   3.00736e+00
#    7  mean         1.01937e+00   4.55388e-05   3.67502e-02  -4.67233e+00
#    8  nBkg         2.16157e+06   2.35722e+03   2.49776e-03  -9.38489e+00
#    9  nSig         5.15751e+04   1.85275e+03   5.77163e-03  -1.28137e+01
#                                ERR DEF= 0.5
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 5 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1.00037 added to diagonal of error matrix
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.61013e+07) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0=-0.764824, a1=-0.259314, a2=1.69457, a4=0.0863172, a5=0.0486966, gamma=0.00803923, mean=1.01948, nBkg=4.99174e+06, nSig=2.04274e+06
# RooChebychev::cheb[ x=mass coefList=(a0,a1,a2,a3,a4,a5) ]
#      p.d.f value is less than zero (-0.099480), forcing value to zero @ x=mass=0.98925, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.049715), forcing value to zero @ x=mass=1.02775, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.119747), forcing value to zero @ x=mass=1.02825, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.187814), forcing value to zero @ x=mass=1.02875, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.253812), forcing value to zero @ x=mass=1.02925, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.317633), forcing value to zero @ x=mass=1.02975, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.379166), forcing value to zero @ x=mass=1.03025, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.438298), forcing value to zero @ x=mass=1.03075, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.494911), forcing value to zero @ x=mass=1.03125, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.548883), forcing value to zero @ x=mass=1.03175, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.600085), forcing value to zero @ x=mass=1.03225, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#      p.d.f value is less than zero (-0.648383), forcing value to zero @ x=mass=1.03275, coefList=(a0 = -0.764824,a1 = -0.259314,a2 = 1.69457,a3 = 0,a4 = 0.0863172,a5 = 0.0486966)
#     ... (remaining 29 messages suppressed)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MACHINE ACCURACY LIMITS FURTHER IMPROVEMENT.
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  MIGRAD TERMINATED WITHOUT CONVERGENCE.
#  FCN=-3.63443e+07 FROM MIGRAD    STATUS=FAILED       1227 CALLS        1228 TOTAL
#                      EDM=0.00259744    STRATEGY= 1      ERR MATRIX APPROXIMATE
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0           4.07935e-01   1.35532e-03   5.05829e-03   2.39529e+00
#    2  a1          -1.60129e-01   1.83175e-03   1.03734e-02  -2.65782e+00
#    3  a2           4.62518e-02   1.20939e-03   2.08012e-03   9.28064e+00
#    4  a4           1.42625e-02   1.14085e-03   4.16777e-02  -4.76389e-01
#    5  a5          -1.37846e-02   1.33060e-03   1.54458e-01   2.85931e-02
#    6  gamma        2.94767e-03   1.70848e-04   1.01948e-01   1.19818e-02
#    7  mean         1.01937e+00   4.54349e-05   3.66027e-02  -5.03450e-01
#    8  nBkg         2.16109e+06   2.36782e+03   2.49780e-03   2.04620e+00
#    9  nSig         5.20683e+04   1.86653e+03   5.75754e-03  -1.12062e+01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  9    ERR DEF=0.5
#   1.837e-06  9.240e-07  8.066e-07  5.360e-07 -3.245e-07  5.557e-08 -3.358e-09 -7.376e-01  7.362e-01
#   9.240e-07  3.355e-06  6.451e-07  4.422e-07 -1.339e-06  1.782e-07  1.656e-09 -2.488e+00  2.483e+00
#   8.066e-07  6.451e-07  1.463e-06  4.941e-07 -1.944e-07  2.933e-08  3.694e-09 -4.103e-01  4.095e-01
#   5.360e-07  4.422e-07  4.941e-07  1.302e-06 -3.669e-07  3.147e-08 -1.044e-08 -4.871e-01  4.860e-01
#  -3.245e-07 -1.339e-06 -1.944e-07 -3.669e-07  1.772e-06 -9.474e-08  1.651e-10  1.532e+00 -1.529e+00
#   5.557e-08  1.782e-07  2.933e-08  3.147e-08 -9.474e-08  2.921e-08  5.774e-10 -2.668e-01  2.665e-01
#  -3.358e-09  1.656e-09  3.694e-09 -1.044e-08  1.651e-10  5.774e-10  2.064e-09 -3.140e-03  3.147e-03
#  -7.376e-01 -2.488e+00 -4.103e-01 -4.871e-01  1.532e+00 -2.668e-01 -3.140e-03  5.607e+06 -3.439e+06
#   7.362e-01  2.483e+00  4.095e-01  4.860e-01 -1.529e+00  2.665e-01  3.147e-03 -3.439e+06  3.484e+06
# ERR MATRIX APPROXIMATE
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8      9
#         1  0.57446   1.000  0.372  0.492  0.347 -0.180  0.240 -0.055 -0.230  0.291
#         2  0.76472   0.372  1.000  0.291  0.212 -0.549  0.569  0.020 -0.574  0.726
#         3  0.56355   0.492  0.291  1.000  0.358 -0.121  0.142  0.067 -0.143  0.181
#         4  0.49522   0.347  0.212  0.358  1.000 -0.242  0.161 -0.201 -0.180  0.228
#         5  0.66371  -0.180 -0.549 -0.121 -0.242  1.000 -0.416  0.003  0.486 -0.615
#         6  0.84645   0.240  0.569  0.142  0.161 -0.416  1.000  0.074 -0.659  0.836
#         7  0.27765  -0.055  0.020  0.067 -0.201  0.003  0.074  1.000 -0.029  0.037
#         8  0.77849  -0.230 -0.574 -0.143 -0.180  0.486 -0.659 -0.029  1.000 -0.778
#         9  0.92656   0.291  0.726  0.181  0.228 -0.615  0.836  0.037 -0.778  1.000
#  ERR MATRIX APPROXIMATE
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        4500
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-3.63443e+07 FROM HESSE     STATUS=OK             77 CALLS        1305 TOTAL
#                      EDM=0.00325825    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  a0           4.07935e-01   1.36963e-03   2.02332e-04   4.20191e-01
#    2  a1          -1.60129e-01   1.95985e-03   4.14936e-04  -3.26002e-01
#    3  a2           4.62518e-02   1.21739e-03   8.32048e-05   2.31280e-02
#    4  a4           1.42625e-02   1.15569e-03   1.66711e-03   1.43113e-01
#    5  a5          -1.37846e-02   1.45009e-03   6.17832e-03   3.91828e+00
#    6  gamma        2.94767e-03   1.82905e-04   4.07794e-03  -6.03085e-01
#    7  mean         1.01937e+00   4.52942e-05   1.46411e-03  -1.26240e-01
#    8  nBkg         2.16109e+06   2.52117e+03   9.99120e-05  -1.35983e-01
#    9  nSig         5.20683e+04   2.06070e+03   2.30302e-04  -1.36635e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  9    ERR DEF=0.5
#   1.876e-06  1.047e-06  8.351e-07  5.737e-07 -4.271e-07  6.734e-08 -3.122e-09 -8.873e-01  8.872e-01
#   1.047e-06  3.841e-06  7.227e-07  5.689e-07 -1.762e-06  2.238e-07  2.849e-09 -3.088e+00  3.088e+00
#   8.351e-07  7.227e-07  1.482e-06  5.186e-07 -2.569e-07  3.581e-08  3.833e-09 -4.999e-01  4.998e-01
#   5.737e-07  5.689e-07  5.186e-07  1.336e-06 -4.741e-07  4.364e-08 -1.008e-08 -6.396e-01  6.395e-01
#  -4.271e-07 -1.762e-06 -2.569e-07 -4.741e-07  2.105e-06 -1.331e-07 -1.167e-09  2.051e+00 -2.050e+00
#   6.734e-08  2.238e-07  3.581e-08  4.364e-08 -1.331e-07  3.348e-08  4.605e-10 -3.240e-01  3.240e-01
#  -3.122e-09  2.849e-09  3.833e-09 -1.008e-08 -1.167e-09  4.605e-10  2.052e-09 -4.186e-03  4.186e-03
#  -8.873e-01 -3.088e+00 -4.999e-01 -6.396e-01  2.051e+00 -3.240e-01 -4.186e-03  6.356e+06 -4.195e+06
#   8.872e-01  3.088e+00  4.998e-01  6.395e-01 -2.050e+00  3.240e-01  4.186e-03 -4.195e+06  4.247e+06
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8      9
#         1  0.58645   1.000  0.390  0.501  0.362 -0.215  0.269 -0.050 -0.257  0.314
#         2  0.79831   0.390  1.000  0.303  0.251 -0.620  0.624  0.032 -0.625  0.765
#         3  0.57142   0.501  0.303  1.000  0.369 -0.145  0.161  0.070 -0.163  0.199
#         4  0.51469   0.362  0.251  0.369  1.000 -0.283  0.206 -0.193 -0.220  0.269
#         5  0.72800  -0.215 -0.620 -0.145 -0.283  1.000 -0.502 -0.018  0.561 -0.686
#         6  0.86836   0.269  0.624  0.161  0.206 -0.502  1.000  0.056 -0.702  0.859
#         7  0.26954  -0.050  0.032  0.070 -0.193 -0.018  0.056  1.000 -0.037  0.045
#         8  0.80779  -0.257 -0.625 -0.163 -0.220  0.561 -0.702 -0.037  1.000 -0.807
#         9  0.94017   0.314  0.765  0.199  0.269 -0.686  0.859  0.045 -0.807  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization

# %%
plotmax = hist.GetMaximum()*1.05
#sidesigma = sigma.getValV()
sidesigma = gamma.getValV()
#sidesigma = 4.76572e-03
leftlowside = -6.*sidesigma + mean.getValV()
leftupside = -4.*sidesigma + mean.getValV()
rightlowside = +4.*sidesigma + mean.getValV()
rightupside = +6.*sidesigma + mean.getValV()

signallow = -3.*sidesigma + mean.getValV()
signalup = +3.*sidesigma + mean.getValV()

print "Side Sigma"
print "%.5e" % sidesigma
print "Left Side"
print "%.5f - %.5f" % (leftlowside,leftupside)
print mean.getValV()
# Out:
# Side Sigma
# 2.94767e-03
# Left Side
# 1.00168 - 1.00758
# 1.01937047694

# %%
for param in [False,True]:
    cmass = TCanvas("canvas","canvas",1200,1200) ;
    JPsi_mass = 3.096916
    Phi_mass = 1.019455
    th_mass = JPsi_mass + Phi_mass

    pullpad = TPad("pullpad","pullpad",0.0,0.05,1.0,0.33)
    plotpad = TPad("histopad","histopad",0.0,0.35,1.0,1.0)
    plotpad.SetFillStyle(4004)
    pullpad.SetFillStyle(4004)
    plotpad.Draw()
    pullpad.Draw()

    massFrame = mass.frame()
    massFrame.SetTitle("Phi signal - CC - NonPrompt")
    dh.plotOn(massFrame,Name("Data"))
    tot.plotOn(massFrame,Name("Pdf"))
    massFrame.GetYaxis().SetTitleOffset(1.3)
    #gauss.plotOn(massFrame,LineColor(kGreen),LineStyle(kDashed),Normalization((sFrac.getValV()*numEvts)/(numEvts)))
    #cheb.plotOn(massFrame,LineColor(kMagenta),LineStyle(kDotted),Normalization(((1.0-sFrac.getValV())*numEvts)/(numEvts)))
    signal.plotOn(massFrame,LineColor(kGreen),LineStyle(kDashed),Normalization((nSig.getValV())/(numEvts)))
    cheb.plotOn(massFrame,LineColor(kGreen),LineStyle(kDashed),Normalization((nBkg.getValV())/(numEvts)))
    if param:
        tot.paramOn(massFrame,Layout(0.60,0.99,0.75))
    plotpad.cd()
    massFrame.Draw()

    linelow = TLine(leftlowside,0.0,leftlowside,plotmax)
    linemidlow = TLine(leftupside,0.0,leftupside,plotmax)
    linemidup = TLine(rightlowside,0.0,rightlowside,plotmax)
    lineup = TLine(rightupside,0.0,rightupside,plotmax)

    linesiglow = TLine(signallow,0.0,signallow,plotmax)
    linesigup = TLine(signalup,0.0,signalup,plotmax)

    linelow.SetLineColor(kRed)
    linemidlow.SetLineColor(kRed)
    linemidup.SetLineColor(kRed)
    lineup.SetLineColor(kRed)

    linesiglow.SetLineColor(kGreen)
    linesigup.SetLineColor(kGreen) 

    linelow.SetLineWidth(2)
    linemidlow.SetLineWidth(2)
    linemidup.SetLineWidth(2)
    lineup.SetLineWidth(2)

    linesiglow.SetLineWidth(2)
    linesigup.SetLineWidth(2) 
    
    if not param:
        linelow.Draw()
        linemidlow.Draw()
        linemidup.Draw()
        lineup.Draw()

        linesiglow.Draw()
        linesigup.Draw()


    hpull = massFrame.pullHist("Data","Pdf")
    pullframe = mass.frame(Title("Pull Distribution"))
    #pullframe.GetXaxis().SetTitleSize(0.04)
    #pullframe.GetYaxis().SetTitleSize(0.03)
    ROOT.gStyle.SetTitleFontSize(0.07)
    pullpad.cd()

    pullframe.addPlotable(hpull,"P")
    pullframe.Draw()
    upLine = TLine(massmin,3.0,massmax,3.0)
    upLine.SetLineColor(kRed)
    upLine.SetLineStyle(kDashed)
    upLine.SetLineWidth(2)
    dwLine = TLine(massmin,-3.0,massmax,-3.0)
    dwLine.SetLineColor(kRed)
    dwLine.SetLineStyle(kDashed)
    dwLine.SetLineWidth(2)
    dwLine.Draw()
    upLine.Draw()
    plotname = "plots/phi_" 
    
    if param:
        plotname += "paramon_"
        
    plotname += histname
    cmass.SaveAs(plotname  + ".png")
    #cmass.SaveAs(plotname  + ".eps")
    cmass.SaveAs(plotname  + ".pdf")
# Out:
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(tot) p.d.f was fitted in range and no explicit plot,norm range was specified, using fit range as default
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(tot) only plotting range 'fit_nll_tot_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(tot) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_tot_dh'
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(tot_Int[mass|fit_nll_tot_dh]_Norm[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(tot) p.d.f was fitted in range and no explicit plot,norm range was specified, using fit range as default
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(tot) only plotting range 'fit_nll_tot_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(tot) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_tot_dh'
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(tot_Int[mass|fit_nll_tot_dh]_Norm[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(signal_Int[mass]) using numeric integrator RooIntegrator1D to calculate Int(mass)
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file plots/phi_SW_PhiMass.png has been created
# Info in <TCanvas::Print>: pdf file plots/phi_SW_PhiMass.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file plots/phi_paramon_SW_PhiMass.png has been created
# Info in <TCanvas::Print>: pdf file plots/phi_paramon_SW_PhiMass.pdf has been created

# %%
Adriano Di Floriomass.setRange("signalrange",signallow,signalup)
mass.setRange("sideleftrange",leftlowside,leftupside)
mass.setRange("siderightrange",rightlowside,rightupside)
signalIntegralBkg = cheb.analyticalIntegral(cheb.getAnalyticalIntegral(RooArgSet(mass),RooArgSet(mass)),"signalrange")
leftsideIntegralBkg = cheb.analyticalIntegral(cheb.getAnalyticalIntegral(RooArgSet(mass),RooArgSet(mass)),"sideleftrange")
rightsideIntegralBkg = cheb.analyticalIntegral(cheb.getAnalyticalIntegral(RooArgSet(mass),RooArgSet(mass)),"siderightrange")
# Out:
# [#1] INFO:Eval -- RooRealVar::setRange(mass) new range named 'signalrange' created with bounds [1.01053,1.02821]
# [#1] INFO:Eval -- RooRealVar::setRange(mass) new range named 'sideleftrange' created with bounds [1.00168,1.00758]
# [#1] INFO:Eval -- RooRealVar::setRange(mass) new range named 'siderightrange' created with bounds [1.03116,1.03706]

# %%
totIntegralBkg = cheb.analyticalIntegral(cheb.getAnalyticalIntegral(RooArgSet(mass),RooArgSet(mass)))

# %%
#sigBkgEvts = signalIntegralBkg/totIntegralBkg*((1.0-sFrac.getValV())*numEvts)
#sidBkgEvts = (leftsideIntegralBkg+rightsideIntegralBkg)/totIntegralBkg*((1.0-sFrac.getValV())*numEvts)
sigBkgEvts = signalIntegralBkg/totIntegralBkg*((nBkg.getValV()))
sidBkgEvts = (leftsideIntegralBkg+rightsideIntegralBkg)/totIntegralBkg*((nBkg.getValV()))

# %%
print sigBkgEvts
# Out:
# 674147.481307

# %%
print sidBkgEvts
# Out:
# 416255.908085

# %%
ratio = sigBkgEvts/sidBkgEvts
print ratio
# Out:
# 1.61955054142

# %%
theRatio = 1.61955054142
siderootfile = "../rootfiles/X4140_Base_AllDatasets.root"
sidefile  = TFile(siderootfile,"READ")

# %%
signalSW = sidefile.Get("SW_Mass_Signal")
sideSW_L = sidefile.Get("SW_Mass_L_Side")
sideSW_R = sidefile.Get("SW_Mass_R_Side")
notrebin = True

# %%
if notrebin:
    signalSW.Rebin(10)
    sideSW_L.Rebin(10)
    sideSW_R.Rebin(10)
    notrebin = False

# %%
#sideSW = sideSW_L.Clone()
#sideSW.Add(sideSW_R)
#sideSW.Scale(ratio)
sideSW_L.Scale(theRatio)
sideSW_R.Scale(theRatio)

# %%
cY = TCanvas("cB0","cB0",1200,800)

signalSW.SetFillColor(kBlue)
signalSW.SetName("X Candidates Mass - SC")
signalSW.SetTitle("X Candidates Mass - SC; M(KK#mu#mu)[GeV]; candidates/" + str(signalSW.GetBinWidth(2)*1000)+ "MeV")
signalSW.GetYaxis().SetTitleOffset(1.3)
#signalSW.SetMarkerColor(kBlack)
signalSW.SetFillStyle(3002)
signalSW.SetMarkerStyle(ROOT.kFullCircle)
signalSW.SetMarkerSize(0.65)
signalSW.SetLineColor(kBlack)

sideSW_L.SetFillColor(kRed)
#sideSW_L.SetMarkerColor(kBlack)
sideSW_L.SetFillStyle(3002)
sideSW_L.SetMarkerStyle(ROOT.kFullCircle)
sideSW_L.SetMarkerSize(0.65)
sideSW_L.SetLineColor(kBlack)

sideSW_R.SetFillColor(kGreen)
#sideSW_R.SetMarkerColor(kBlack)
sideSW_R.SetMarkerStyle(ROOT.kFullCircle)
sideSW_R.SetMarkerSize(0.65)
sideSW_R.SetLineColor(kBlack)
sideSW_R.SetFillStyle(3002)

side = sideSW_R.Clone()
side.Add(sideSW_L,1.0)

signalSW.Draw("EBar")
#sideSW = sideSW_L.Clone()
#sideSW.Add(sideSW_R,+1.0)
#sideSW.SetFillColor(kRed)
#sideSW.SetFillStyle(3002)
#sideSW.Scale(2.0)
#sideSW.Draw("SAMEBar")
sideSW_R.Draw("E0SAMEBar")
sideSW_L.Draw("E0SAMEBar")
#side.Draw("E0SAMEBar")

legend = TLegend(0.75,0.45,0.99,0.75)
legend.AddEntry(signalSW,"Signal region (-3.0#sigma,+3.0#sigma)","f")
legend.AddEntry(sideSW_R,"R-sideband    (+4.0#sigma,+6.0#sigma)","f")
legend.AddEntry(sideSW_L,"L-sideband    (-6.0#sigma,-4.0#sigma)","f")
legend.Draw()
cY.SaveAs("plots/" + signalSW.GetName() + "_sidebands.png")
cY.SaveAs("plots/" + signalSW.GetName() + "_sidebands.pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: cB0
# Info in <TCanvas::Print>: png file plots/X Candidates Mass - SC_sidebands.png has been created
# Info in <TCanvas::Print>: pdf file plots/X Candidates Mass - SC_sidebands.pdf has been created

# %%
Adriano Di FlorioROOT.gStyle.SetOptStat(0)
ySideSub = signalSW.Clone("SW Mass")
ySideSub.SetTitle("X Mass - #phi sides subtracted; M(KK#mu#mu)[GeV]; candidates/" + str(signalSW.GetBinWidth(2)*1000)+ "MeV")
ySideSub.GetYaxis().SetTitleOffset(1.2)
#ySideSub.Add(sideSW,-1.0) 
ySideSub.Add(sideSW_L,-1.0)
ySideSub.Add(sideSW_R,-1.0)
# Out:
# True

# %%
ySideSub.SetFillColor(4004)
ySideSub.SetFillStyle(3002)
ySideSub.SetMarkerStyle(ROOT.kFullCircle)
ySideSub.SetMarkerColor(kBlack)
ySideSub.SetMarkerSize(0.8)
ySideSub.SetLineColor(kBlack)
ySideSub.Draw("E0")
lineth = TLine(th_mass,ySideSub.GetMinimum()*1.25,th_mass,ySideSub.GetMaximum()*1.1)
lineth.SetLineColor(kBlue)
lineth.SetLineWidth(2)
lineth.SetLineStyle(kDashed)
lineth.Draw()
linezero = TLine(ySideSub.GetBinCenter(1),0.0,ySideSub.GetBinCenter(ySideSub.GetNbinsX()),0.0)
linezero.SetLineColor(kRed)
linezero.SetLineWidth(2)
linezero.SetLineStyle(kDotted)
linezero.Draw()
cY.SaveAs("plots/" + signalSW.GetName() + "_subtracted.png")
cY.SaveAs("plots/" + signalSW.GetName() + "_subtracted.pdf")

# %%
plt.hist([],range=[4.0,6.0],bins=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa16769be535> in <module>()
# ----> 1 plt.hist([],range=[4.0,6.0],bins=100)
#
# NameError: name 'plt' is not defined

# %%
cands =np.array([533778.0, 464027.0, 398157.0, 311156.0, 217232.0, 146840.0, 95795.0])
cuts = [4.0,4.2,4.3,4.4,4.6,4.8,5.0]
rates = np.array([23.,23.,22.61,21.39,18.97,17.36,15.34])
plt.scatter(cuts,cands)
plt.title("Candidates vs mass cut")
plt.xlabel("masscut")
plt.ylabel("rate [Hz]")
plt.show()

# %%
cuts = [4.0,4.2,4.3,4.4,4.6,4.8,5.0]
plt.scatter(cuts,rates)
plt.title("Rate vs mass cut")
plt.xlabel("masscut")
plt.ylabel("rate [Hz]")
plt.show()
